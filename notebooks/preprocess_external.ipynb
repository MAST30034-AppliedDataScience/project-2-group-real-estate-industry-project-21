# %% [markdown]
# # Pre-process External Datasets
#
# Perform basic data type transformations and column renaming on external datasets and save into `raw` folder

# %%
import os
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## ABS SA2 Boundary Shapefile

# %% [markdown]
# Read file

# %%
sf = gpd.read_file("../data/landing/sa2_data/boundary/SA2_2021_AUST_GDA2020.shp")

sf.head()
# Out:
#   SA2_CODE21                       SA2_NAME21 CHG_FLAG21  CHG_LBL21  \
# 0  101021007                        Braidwood          0  No change
# 1  101021008                          Karabar          0  No change
# 2  101021009                       Queanbeyan          0  No change
# 3  101021010                Queanbeyan - East          0  No change
# 4  101021012  Queanbeyan West - Jerrabomberra          0  No change
#
#   SA3_CODE21  SA3_NAME21 SA4_CODE21      SA4_NAME21 GCC_CODE21   GCC_NAME21  \
# 0      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 1      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 2      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 3      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 4      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
#
#   STE_CODE21       STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 0          1  New South Wales        AUS  Australia   3418.3525
# 1          1  New South Wales        AUS  Australia      6.9825
# 2          1  New South Wales        AUS  Australia      4.7620
# 3          1  New South Wales        AUS  Australia     13.0032
# 4          1  New South Wales        AUS  Australia     13.6748
#
#                                           LOCI_URI21  \
# 0  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 3  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 4  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                             geometry
# 0  POLYGON ((149.58424 -35.44426, 149.58444 -35.4...
# 1  POLYGON ((149.21899 -35.36738, 149.218 -35.366...
# 2  POLYGON ((149.21326 -35.34325, 149.21619 -35.3...
# 3  POLYGON ((149.24034 -35.34781, 149.24024 -35.3...
# 4  POLYGON ((149.19572 -35.36126, 149.1997 -35.35...

# %%
sf.columns
# Out:
# Index(['SA2_CODE21', 'SA2_NAME21', 'CHG_FLAG21', 'CHG_LBL21', 'SA3_CODE21',
#        'SA3_NAME21', 'SA4_CODE21', 'SA4_NAME21', 'GCC_CODE21', 'GCC_NAME21',
#        'STE_CODE21', 'STE_NAME21', 'AUS_CODE21', 'AUS_NAME21', 'AREASQKM21',
#        'LOCI_URI21', 'geometry'],
#       dtype='object')

# %% [markdown]
# Edit column names to make them a consistent case and consistent with other datasets

# %%
# Removes "21" from the string, and converts to lowercase
sf.columns = [c.replace("21", "").lower() for c in sf.columns]

sf.columns
# Out:
# Index(['sa2_code', 'sa2_name', 'chg_flag', 'chg_lbl', 'sa3_code', 'sa3_name',
#        'sa4_code', 'sa4_name', 'gcc_code', 'gcc_name', 'ste_code', 'ste_name',
#        'aus_code', 'aus_name', 'areasqkm', 'loci_uri', 'geometry'],
#       dtype='object')

# %% [markdown]
# Check data types

# %%
sf.dtypes
# Out:
# sa2_code      object
# sa2_name      object
# chg_flag      object
# chg_lbl       object
# sa3_code      object
# sa3_name      object
# sa4_code      object
# sa4_name      object
# gcc_code      object
# gcc_name      object
# ste_code      object
# ste_name      object
# aus_code      object
# aus_name      object
# areasqkm     float64
# loci_uri      object
# geometry    geometry
# dtype: object

# %% [markdown]
# Save into raw folder

# %%
sf_dir = "../data/raw/sa2_data/boundary"

# Create a new sub-folder if one doesn't already exist
if not os.path.exists(sf_dir):
    os.makedirs(sf_dir)

sf_output = f"{sf_dir}/sa2_boundary.shp"

sf.to_file(sf_output)

# %% [markdown]
# ## ABS SA2 Historical Population Data

# %% [markdown]
# Read file, ignoring excess formatting cells

# %%
pop_df = pd.read_excel("../data/landing/sa2_data/sa2_population_2001-23.xlsx", 
                       sheet_name = "Table 1", header = [5, 6], skipfooter = 2)

pop_df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#           GCCSA code         GCCSA name           SA4 code           SA4 name
# 0              1RNSW        Rest of NSW                101     Capital Region
# 1              1RNSW        Rest of NSW                101     Capital Region
# 2              1RNSW        Rest of NSW                101     Capital Region
# 3              1RNSW        Rest of NSW                101     Capital Region
# 4              1RNSW        Rest of NSW                101     Capital Region
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0  \
#             SA3 code           SA3 name           SA2 code
# 0              10102         Queanbeyan          101021007
# 1              10102         Queanbeyan          101021008
# 2              10102         Queanbeyan          101021009
# 3              10102         Queanbeyan          101021010
# 4              10102         Queanbeyan          101021012
#
#                 Unnamed: 7_level_0  2001   2002  ...   2014   2015   2016  \
#                           SA2 name   no.    no.  ...    no.    no.    no.
# 0                        Braidwood  2760   2811  ...   3762   3849   3950
# 1                          Karabar  9129   9199  ...   8731   8603   8531
# 2                       Queanbeyan  9717   9513  ...  11199  11213  11230
# 3                Queanbeyan - East  3925   4073  ...   4967   4961   4970
# 4  Queanbeyan West - Jerrabomberra  9425  10257  ...  13193  13164  13150
#
#     2017   2018   2019   2020   2021   2022   2023
#      no.    no.    no.    no.    no.    no.    no.
# 0   4041   4145   4218   4282   4332   4366   4396
# 1   8530   8516   8500   8535   8548   8528   8483
# 2  11362  11460  11468  11460  11375  11391  11420
# 3   5016   5079   5126   5089   5097   5091   5099
# 4  13090  13022  12955  12821  12748  12781  12873
#
# [5 rows x 31 columns]

# %%
pop_df.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0', 'GCCSA code'),
#             ('Unnamed: 1_level_0', 'GCCSA name'),
#             ('Unnamed: 2_level_0',   'SA4 code'),
#             ('Unnamed: 3_level_0',   'SA4 name'),
#             ('Unnamed: 4_level_0',   'SA3 code'),
#             ('Unnamed: 5_level_0',   'SA3 name'),
#             ('Unnamed: 6_level_0',   'SA2 code'),
#             ('Unnamed: 7_level_0',   'SA2 name'),
#             (                2001,        'no.'),
#             (                2002,        'no.'),
#             (                2003,        'no.'),
#             (                2004,        'no.'),
#             (                2005,        'no.'),
#             (                2006,        'no.'),
#             (                2007,        'no.'),
#             (                2008,        'no.'),
#             (                2009,        'no.'),
#             (                2010,        'no.'),
#             (                2011,        'no.'),
#             (                2012,        'no.'),
#             (                2013,        'no.'),
#             (                2014,        'no.'),
#             (                2015,        'no.'),
#             (                2016,        'no.'),
#             (                2017,        'no.'),
#             (                2018,        'no.'),
#             (                2019,        'no.'),
#             (                2020,        'no.'),
#             (                2021,        'no.'),
#             (                2022,        'no.'),
#             (                2023,        'no.')],
#            )

# %% [markdown]
# Edit column names for clarity and consistency with other datasets

# %%
# List to hold new column names
pop_new_cols = []

for i in range(len(pop_df.columns)):

    # For the first 8 columns, take the second part of the multi-header 
    # Rename "gccsa" to "gcc" for consistency with other datasets
    if i < 8:
        pop_new_cols.append(pop_df.columns[i][1]
                            .lower() # Convert to lowercase
                            .replace(" ", "_") # Replace whitespace with _
                            .replace("gccsa", "gcc") # Replace "gccsa" with "gcc"
                            )

    # For the rest of the columns, take the first part of the multi-header    
    else:
        pop_new_cols.append(str(pop_df.columns[i][0]))

pop_new_cols
# Out:
# ['gcc_code',
#  'gcc_name',
#  'sa4_code',
#  'sa4_name',
#  'sa3_code',
#  'sa3_name',
#  'sa2_code',
#  'sa2_name',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023']

# %% [markdown]
# Assign new column names

# %%
pop_df.columns = pop_new_cols

pop_df.head()
# Out:
#   gcc_code     gcc_name  sa4_code        sa4_name  sa3_code    sa3_name  \
# 0    1RNSW  Rest of NSW       101  Capital Region     10102  Queanbeyan
# 1    1RNSW  Rest of NSW       101  Capital Region     10102  Queanbeyan
# 2    1RNSW  Rest of NSW       101  Capital Region     10102  Queanbeyan
# 3    1RNSW  Rest of NSW       101  Capital Region     10102  Queanbeyan
# 4    1RNSW  Rest of NSW       101  Capital Region     10102  Queanbeyan
#
#     sa2_code                         sa2_name  2001   2002  ...   2014   2015  \
# 0  101021007                        Braidwood  2760   2811  ...   3762   3849
# 1  101021008                          Karabar  9129   9199  ...   8731   8603
# 2  101021009                       Queanbeyan  9717   9513  ...  11199  11213
# 3  101021010                Queanbeyan - East  3925   4073  ...   4967   4961
# 4  101021012  Queanbeyan West - Jerrabomberra  9425  10257  ...  13193  13164
#
#     2016   2017   2018   2019   2020   2021   2022   2023
# 0   3950   4041   4145   4218   4282   4332   4366   4396
# 1   8531   8530   8516   8500   8535   8548   8528   8483
# 2  11230  11362  11460  11468  11460  11375  11391  11420
# 3   4970   5016   5079   5126   5089   5097   5091   5099
# 4  13150  13090  13022  12955  12821  12748  12781  12873
#
# [5 rows x 31 columns]

# %% [markdown]
# Check data types

# %%
pop_df.dtypes
# Out:
# gcc_code    object
# gcc_name    object
# sa4_code     int64
# sa4_name    object
# sa3_code     int64
# sa3_name    object
# sa2_code     int64
# sa2_name    object
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009         int64
# 2010         int64
# 2011         int64
# 2012         int64
# 2013         int64
# 2014         int64
# 2015         int64
# 2016         int64
# 2017         int64
# 2018         int64
# 2019         int64
# 2020         int64
# 2021         int64
# 2022         int64
# 2023         int64
# dtype: object

# %% [markdown]
# Save into raw folder

# %%
pop_df_dir = "../data/raw/sa2_data"

# Create a new sub-folder if one doesn't already exist
if not os.path.exists(pop_df_dir):
    os.makedirs(pop_df_dir)

pop_df_output = f"{pop_df_dir}/sa2_population_2001-23.csv"

pop_df.to_csv(pop_df_output, index = False)

# %% [markdown]
# ## ABS SA2 Income Data

# %% [markdown]
# Read file, ignoring excess formatting cells

# %%
income_df = pd.read_excel("../data/landing/sa2_data/sa2_income_2021.xlsx", 
                          sheet_name = "Table 2.4", header = [5, 6], skipfooter = 5, 
                          thousands = ",", na_values = "np")

income_df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0     Earners Median age of earners  \
#                  SA2           SA2 NAME   (persons)                 years
# 0          Australia                NaN  14760008.0                  42.0
# 1    New South Wales                NaN   4603736.0                  42.0
# 2          101021007          Braidwood      2467.0                  51.0
# 3          101021008            Karabar      5103.0                  42.0
# 4          101021009         Queanbeyan      7028.0                  39.0
#
#             Sum   Median     Mean P80/P20 P80/P50 P20/P50 P10/P50  \
#               $        $        $   ratio   ratio   ratio   ratio
# 0  1.040901e+12  54890.0  70522.0    5.00    1.88    0.38    0.14
# 1  3.411075e+11  55854.0  74094.0    5.00    1.90    0.38    0.15
# 2  1.699867e+08  46640.0  68904.0    6.84    2.05    0.30    0.07
# 3  3.555383e+08  65564.0  69672.0    3.37    1.57    0.47    0.23
# 4  4.861574e+08  63528.0  69174.0    3.24    1.58    0.49    0.26
#
#   Gini coefficient Top 1% Top 5% Top 10% Lowest Quartile Second Quartile  \
#              coef.      %      %       %               %               %
# 0            0.483    9.8   22.5    33.4            25.0            25.0
# 1            0.497   11.2   24.3    35.2            24.6            24.6
# 2            0.615   21.2   32.6    42.7            31.8            24.3
# 3            0.365    4.4   14.5    24.1            17.8            22.6
# 4            0.368    4.6   14.7    24.5            16.8            24.0
#
#   Third Quartile Highest Quartile
#                %                %
# 0           25.0             25.0
# 1           24.7             26.1
# 2           21.7             22.2
# 3           32.9             26.7
# 4           33.4             25.7

# %%
income_df.columns
# Out:
# MultiIndex([(   'Unnamed: 0_level_0',       'SA2'),
#             (   'Unnamed: 1_level_0',  'SA2 NAME'),
#             (              'Earners', '(persons)'),
#             ('Median age of earners',     'years'),
#             (                  'Sum',         '$'),
#             (               'Median',         '$'),
#             (                 'Mean',         '$'),
#             (              'P80/P20',     'ratio'),
#             (              'P80/P50',     'ratio'),
#             (              'P20/P50',     'ratio'),
#             (              'P10/P50',     'ratio'),
#             (     'Gini coefficient',     'coef.'),
#             (               'Top 1%',         '%'),
#             (               'Top 5%',         '%'),
#             (              'Top 10%',         '%'),
#             (      'Lowest Quartile',         '%'),
#             (      'Second Quartile',         '%'),
#             (       'Third Quartile',         '%'),
#             (     'Highest Quartile',         '%')],
#            )

# %% [markdown]
# Edit column names for clarity and consistency with other datasets

# %%
# List to hold new column names
income_new_cols = []

for i in range(len(income_df.columns)):

    # For the first 2 columns, take the second part of the multi-header 
    if i < 2:
        income_new_cols.append(income_df.columns[i][1]
                            .lower() # Convert to lowercase
                            .replace(" ", "_") # Replace whitespace with _
                            )

    # For the rest of the columns, take the first part of the multi-header    
    else:
        income_new_cols.append(income_df.columns[i][0]
                               .lower() # Convert to lowercase
                               .replace(" ", "_")) # Replace whitespace with _

income_new_cols
# Out:
# ['sa2',
#  'sa2_name',
#  'earners',
#  'median_age_of_earners',
#  'sum',
#  'median',
#  'mean',
#  'p80/p20',
#  'p80/p50',
#  'p20/p50',
#  'p10/p50',
#  'gini_coefficient',
#  'top_1%',
#  'top_5%',
#  'top_10%',
#  'lowest_quartile',
#  'second_quartile',
#  'third_quartile',
#  'highest_quartile']

# %% [markdown]
# Other datasets have `sa2_code` instead of `sa2`. Change for consistency with other datasets

# %%
income_new_cols[0] = "sa2_code"

# %% [markdown]
# Assign new column names

# %%
income_df.columns = income_new_cols

income_df.head()
# Out:
#           sa2_code    sa2_name     earners  median_age_of_earners  \
# 0        Australia         NaN  14760008.0                   42.0
# 1  New South Wales         NaN   4603736.0                   42.0
# 2        101021007   Braidwood      2467.0                   51.0
# 3        101021008     Karabar      5103.0                   42.0
# 4        101021009  Queanbeyan      7028.0                   39.0
#
#             sum   median     mean  p80/p20  p80/p50  p20/p50  p10/p50  \
# 0  1.040901e+12  54890.0  70522.0     5.00     1.88     0.38     0.14
# 1  3.411075e+11  55854.0  74094.0     5.00     1.90     0.38     0.15
# 2  1.699867e+08  46640.0  68904.0     6.84     2.05     0.30     0.07
# 3  3.555383e+08  65564.0  69672.0     3.37     1.57     0.47     0.23
# 4  4.861574e+08  63528.0  69174.0     3.24     1.58     0.49     0.26
#
#    gini_coefficient  top_1%  top_5%  top_10%  lowest_quartile  \
# 0             0.483     9.8    22.5     33.4             25.0
# 1             0.497    11.2    24.3     35.2             24.6
# 2             0.615    21.2    32.6     42.7             31.8
# 3             0.365     4.4    14.5     24.1             17.8
# 4             0.368     4.6    14.7     24.5             16.8
#
#    second_quartile  third_quartile  highest_quartile
# 0             25.0            25.0              25.0
# 1             24.6            24.7              26.1
# 2             24.3            21.7              22.2
# 3             22.6            32.9              26.7
# 4             24.0            33.4              25.7

# %% [markdown]
# Check data types

# %%
income_df.dtypes
# Out:
# sa2_code                  object
# sa2_name                  object
# earners                  float64
# median_age_of_earners    float64
# sum                      float64
# median                   float64
# mean                     float64
# p80/p20                  float64
# p80/p50                  float64
# p20/p50                  float64
# p10/p50                  float64
# gini_coefficient         float64
# top_1%                   float64
# top_5%                   float64
# top_10%                  float64
# lowest_quartile          float64
# second_quartile          float64
# third_quartile           float64
# highest_quartile         float64
# dtype: object

# %% [markdown]
# Save into raw folder

# %%
income_df_dir = "../data/raw/sa2_data"

# Create a new sub-folder if one doesn't already exist
if not os.path.exists(income_df_dir):
    os.makedirs(income_df_dir)

income_df_output = f"{income_df_dir}/sa2_income_2021.csv"

income_df.to_csv(income_df_output, index = False)

# %% [markdown]
# ## Department of Education School Location Data

# %% [markdown]
# Read file

# %%
school_df = pd.read_csv("../data/landing/school_data/school_location.csv", encoding_errors='replace')

school_df.head()
# Out:
#   Education_Sector  Entity_Type  School_No  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# 3  40 Anderson Street            NaN       Avenel           VIC  ...
# 4  5-11 Forbes Street            NaN   Warrandyte           VIC  ...
#
#    Postal_Address_Line_1 Postal_Address_Line_2 Postal_Town Postal_State  \
# 0      21 Thomson Street                   NaN    ALBERTON          VIC
# 1           Frank Street                   NaN  ALLANSFORD          VIC
# 2             P O Box 12                   NaN       AVOCA          VIC
# 3     40 Anderson Street                   NaN      AVENEL          VIC
# 4     5-11 Forbes Street                   NaN  WARRANDYTE          VIC
#
#   Postal_Postcode  Full_Phone_No LGA_ID         LGA_Name          X         Y
# 0            3971   03 5183 2412    681   Wellington (S)  146.66660 -38.61771
# 1            3277   03 5565 1382    673  Warrnambool (C)  142.59039 -38.38628
# 2            3467   03 5465 3176    599     Pyrenees (S)  143.47565 -37.08450
# 3            3664   03 5796 2264    643  Strathbogie (S)  145.23472 -36.90137
# 4            3113   03 9844 3537    421   Manningham (C)  145.21398 -37.74268
#
# [5 rows x 21 columns]

# %%
school_df.columns
# Out:
# Index(['Education_Sector', 'Entity_Type', 'School_No', 'School_Name',
#        'School_Type', 'School_Status', 'Address_Line_1', 'Address_Line_2',
#        'Address_Town', 'Address_State', 'Address_Postcode',
#        'Postal_Address_Line_1', 'Postal_Address_Line_2', 'Postal_Town',
#        'Postal_State', 'Postal_Postcode', 'Full_Phone_No', 'LGA_ID',
#        'LGA_Name', 'X', 'Y'],
#       dtype='object')

# %% [markdown]
# Make column name casing consistent

# %%
school_df.columns = [c.lower() for c in school_df.columns]

school_df.columns
# Out:
# Index(['education_sector', 'entity_type', 'school_no', 'school_name',
#        'school_type', 'school_status', 'address_line_1', 'address_line_2',
#        'address_town', 'address_state', 'address_postcode',
#        'postal_address_line_1', 'postal_address_line_2', 'postal_town',
#        'postal_state', 'postal_postcode', 'full_phone_no', 'lga_id',
#        'lga_name', 'x', 'y'],
#       dtype='object')

# %% [markdown]
# Check data types

# %%
school_df.dtypes
# Out:
# education_sector          object
# entity_type                int64
# school_no                  int64
# school_name               object
# school_type               object
# school_status             object
# address_line_1            object
# address_line_2            object
# address_town              object
# address_state             object
# address_postcode           int64
# postal_address_line_1     object
# postal_address_line_2     object
# postal_town               object
# postal_state              object
# postal_postcode            int64
# full_phone_no             object
# lga_id                     int64
# lga_name                  object
# x                        float64
# y                        float64
# dtype: object

# %% [markdown]
# Save into raw folder

# %%
school_df_dir = "../data/raw/school_data"

# Create a new sub-folder if one doesn't already exist
if not os.path.exists(school_df_dir):
    os.makedirs(school_df_dir)

school_df_output = f"{school_df_dir}/school_location.csv"

school_df.to_csv(school_df_output, index = False)

# %% [markdown]
# ## DFFH Suburb Historical Rent Data

# %% [markdown]
# Read file, ignoring excess formatting cells

# %%
rent_df = pd.read_excel("../data/landing/suburb_data/suburb_rent_hist.xlsx", 
                        sheet_name = "All properties", header = [1, 2], 
                        index_col = [0, 1], na_values = "-")

rent_df.head()
# Out:
# All properties                                        Mar 2000         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda   1143.0  260.0
#                 Armadale                                 733.0  200.0
#                 Carlton North                            864.0  260.0
#                 Carlton-Parkville                       1339.0  260.0
#                 CBD-St Kilda Rd                         2132.0  320.0
#
# All properties                                        Jun 2000         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda     1134    260
#                 Armadale                                   737    200
#                 Carlton North                              814    260
#                 Carlton-Parkville                         1304    260
#                 CBD-St Kilda Rd                           2264    320
#
# All properties                                        Sep 2000         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda   1177.0  270.0
#                 Armadale                                 738.0  205.0
#                 Carlton North                            799.0  265.0
#                 Carlton-Parkville                       1300.0  260.0
#                 CBD-St Kilda Rd                         2358.0  320.0
#
# All properties                                        Dec 2000         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda   1178.0  275.0
#                 Armadale                                 739.0  210.0
#                 Carlton North                            736.0  270.0
#                 Carlton-Parkville                       1320.0  260.0
#                 CBD-St Kilda Rd                         2361.0  320.0
#
# All properties                                        Mar 2001         ...  \
#                                                          Count Median  ...
# Inner Melbourne Albert Park-Middle Park-West St Kilda   1208.0  275.0  ...
#                 Armadale                                 718.0  215.0  ...
#                 Carlton North                            718.0  270.0  ...
#                 Carlton-Parkville                       1273.0  260.0  ...
#                 CBD-St Kilda Rd                         2591.0  320.0  ...
#
# All properties                                        Mar 2022         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda      867    500
#                 Armadale                                   805    430
#                 Carlton North                              581    580
#                 Carlton-Parkville                         6143    310
#                 CBD-St Kilda Rd                          17845    365
#
# All properties                                        Jun 2022         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda      855    515
#                 Armadale                                   851    450
#                 Carlton North                              535    595
#                 Carlton-Parkville                         6018    319
#                 CBD-St Kilda Rd                          16792    390
#
# All properties                                        Sep 2022         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda      881    500
#                 Armadale                                   852    450
#                 Carlton North                              547    600
#                 Carlton-Parkville                         6871    340
#                 CBD-St Kilda Rd                          18284    419
#
# All properties                                        Dec 2022         \
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda      832    525
#                 Armadale                                   840    460
#                 Carlton North                              546    600
#                 Carlton-Parkville                         6627    350
#                 CBD-St Kilda Rd                          17627    450
#
# All properties                                        Mar 2023
#                                                          Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda      786    545
#                 Armadale                                   751    490
#                 Carlton North                              490    620
#                 Carlton-Parkville                         6690    400
#                 CBD-St Kilda Rd                          17426    500
#
# [5 rows x 186 columns]

# %%
rent_df.columns
# Out:
# MultiIndex([('Mar 2000',  'Count'),
#             ('Mar 2000', 'Median'),
#             ('Jun 2000',  'Count'),
#             ('Jun 2000', 'Median'),
#             ('Sep 2000',  'Count'),
#             ('Sep 2000', 'Median'),
#             ('Dec 2000',  'Count'),
#             ('Dec 2000', 'Median'),
#             ('Mar 2001',  'Count'),
#             ('Mar 2001', 'Median'),
#             ...
#             ('Mar 2022',  'Count'),
#             ('Mar 2022', 'Median'),
#             ('Jun 2022',  'Count'),
#             ('Jun 2022', 'Median'),
#             ('Sep 2022',  'Count'),
#             ('Sep 2022', 'Median'),
#             ('Dec 2022',  'Count'),
#             ('Dec 2022', 'Median'),
#             ('Mar 2023',  'Count'),
#             ('Mar 2023', 'Median')],
#            names=['All properties', None], length=186)

# %% [markdown]
# Combine column headings and make a consistent case

# %%
rent_df.columns = [f"{i}_{j}".lower().replace(" ", "_") for i, j in rent_df.columns]

rent_df.head()
# Out:
#                                                        mar_2000_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda          1143.0
#                 Armadale                                        733.0
#                 Carlton North                                   864.0
#                 Carlton-Parkville                              1339.0
#                 CBD-St Kilda Rd                                2132.0
#
#                                                        mar_2000_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda            260.0
#                 Armadale                                         200.0
#                 Carlton North                                    260.0
#                 Carlton-Parkville                                260.0
#                 CBD-St Kilda Rd                                  320.0
#
#                                                        jun_2000_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda            1134
#                 Armadale                                          737
#                 Carlton North                                     814
#                 Carlton-Parkville                                1304
#                 CBD-St Kilda Rd                                  2264
#
#                                                        jun_2000_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda              260
#                 Armadale                                           200
#                 Carlton North                                      260
#                 Carlton-Parkville                                  260
#                 CBD-St Kilda Rd                                    320
#
#                                                        sep_2000_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda          1177.0
#                 Armadale                                        738.0
#                 Carlton North                                   799.0
#                 Carlton-Parkville                              1300.0
#                 CBD-St Kilda Rd                                2358.0
#
#                                                        sep_2000_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda            270.0
#                 Armadale                                         205.0
#                 Carlton North                                    265.0
#                 Carlton-Parkville                                260.0
#                 CBD-St Kilda Rd                                  320.0
#
#                                                        dec_2000_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda          1178.0
#                 Armadale                                        739.0
#                 Carlton North                                   736.0
#                 Carlton-Parkville                              1320.0
#                 CBD-St Kilda Rd                                2361.0
#
#                                                        dec_2000_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda            275.0
#                 Armadale                                         210.0
#                 Carlton North                                    270.0
#                 Carlton-Parkville                                260.0
#                 CBD-St Kilda Rd                                  320.0
#
#                                                        mar_2001_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda          1208.0
#                 Armadale                                        718.0
#                 Carlton North                                   718.0
#                 Carlton-Parkville                              1273.0
#                 CBD-St Kilda Rd                                2591.0
#
#                                                        mar_2001_median  ...  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda            275.0  ...
#                 Armadale                                         215.0  ...
#                 Carlton North                                    270.0  ...
#                 Carlton-Parkville                                260.0  ...
#                 CBD-St Kilda Rd                                  320.0  ...
#
#                                                        mar_2022_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda             867
#                 Armadale                                          805
#                 Carlton North                                     581
#                 Carlton-Parkville                                6143
#                 CBD-St Kilda Rd                                 17845
#
#                                                        mar_2022_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda              500
#                 Armadale                                           430
#                 Carlton North                                      580
#                 Carlton-Parkville                                  310
#                 CBD-St Kilda Rd                                    365
#
#                                                        jun_2022_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda             855
#                 Armadale                                          851
#                 Carlton North                                     535
#                 Carlton-Parkville                                6018
#                 CBD-St Kilda Rd                                 16792
#
#                                                        jun_2022_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda              515
#                 Armadale                                           450
#                 Carlton North                                      595
#                 Carlton-Parkville                                  319
#                 CBD-St Kilda Rd                                    390
#
#                                                        sep_2022_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda             881
#                 Armadale                                          852
#                 Carlton North                                     547
#                 Carlton-Parkville                                6871
#                 CBD-St Kilda Rd                                 18284
#
#                                                        sep_2022_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda              500
#                 Armadale                                           450
#                 Carlton North                                      600
#                 Carlton-Parkville                                  340
#                 CBD-St Kilda Rd                                    419
#
#                                                        dec_2022_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda             832
#                 Armadale                                          840
#                 Carlton North                                     546
#                 Carlton-Parkville                                6627
#                 CBD-St Kilda Rd                                 17627
#
#                                                        dec_2022_median  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda              525
#                 Armadale                                           460
#                 Carlton North                                      600
#                 Carlton-Parkville                                  350
#                 CBD-St Kilda Rd                                    450
#
#                                                        mar_2023_count  \
# Inner Melbourne Albert Park-Middle Park-West St Kilda             786
#                 Armadale                                          751
#                 Carlton North                                     490
#                 Carlton-Parkville                                6690
#                 CBD-St Kilda Rd                                 17426
#
#                                                        mar_2023_median
# Inner Melbourne Albert Park-Middle Park-West St Kilda              545
#                 Armadale                                           490
#                 Carlton North                                      620
#                 Carlton-Parkville                                  400
#                 CBD-St Kilda Rd                                    500
#
# [5 rows x 186 columns]

# %% [markdown]
# Check data types

# %%
rent_df.dtypes
# Out:
# mar_2000_count     float64
# mar_2000_median    float64
# jun_2000_count       int64
# jun_2000_median      int64
# sep_2000_count     float64
#                     ...
# sep_2022_median      int64
# dec_2022_count       int64
# dec_2022_median      int64
# mar_2023_count       int64
# mar_2023_median      int64
# Length: 186, dtype: object

# %% [markdown]
# Save into raw folder

# %%
rent_df_dir = "../data/raw/suburb_data"

# Create a new sub-folder if one doesn't already exist
if not os.path.exists(rent_df_dir):
    os.makedirs(rent_df_dir)

rent_df_output = f"{rent_df_dir}/suburb_rent_hist.csv"

rent_df.to_csv(rent_df_output)
